# %% [markdown]
# # Low priced stocks

# %% [markdown]
# Webscraping

# %%
import requests

url='https://www.moneycontrol.com/stocks/marketstats/bse-mostactive-stocks/low-price-high-volume-98/'

page=requests.get(url)

from bs4 import BeautifulSoup

soup=BeautifulSoup(page.content,'html.parser')
# print(soup)

# %%
#Extrating need information from the page content

s_table=soup.findAll('div',class_='bsr_table hist_tbl_hm')
s_table=s_table[0]
# print(s_table)

# %%
#Copying the table header by targeting <th> tag

s_head=s_table.findAll('th')
s_head=[i.text.strip() for i in s_head]
s_head=s_head[:7]
print(s_head)
# Out:
# ['Company Name', 'Group', 'High', 'Low', 'Last Price', '% Chg', 'Value (Rs. cr.)']

# %%
import pandas as pd
import numpy as np

sdf=pd.DataFrame(columns=s_head)
sdf
# Out:
# Empty DataFrame
# Columns: [Company Name, Group, High, Low, Last Price, % Chg, Value (Rs. cr.)]
# Index: []

# %%
# Function to seprate unwanted content

def red(str):
  s=''
  for i in str:
    if i=='\n':
      break
    else:
      s+=i
  return(s)

# %%
#Filtering data from <td>tag

name=s_table.findAll('td',class_='PR')
name=[i.text for i in name]
# print(name)
com_name=[]
for i in name:
  com_name.append(red(i))

print(com_name)
# Out:
# ['Yes Bank', 'Vodafone Idea', 'Jaiprakash Pow', 'Rattan Power', 'Unitech', 'Dish TV', 'SEPC', 'Hathway Cable', 'Alok Industries', 'Brightcom Group', 'SEACOAST SS', 'Zee Media', 'Rajnish Wellnes', 'Rajnish Wellnes', 'Rajnish Wellnes', 'Jaiprakash Asso', 'GTL Infra', 'Pressure Sentiv', 'Pressure Sentiv', 'Nila Infra', 'Vakrangee', 'Urja Global', 'FCS Software', 'Alstone Text', 'Alstone Text', 'Vikas Life', 'Vivanta Industr', 'Vivanta Industr', 'Galactico Corp', 'Akshar Spintex', 'Akshar Spintex', 'Ducon Infratech', 'KBC Global', 'Reliance Home F', 'Madhav Infra Pr', 'Steel Exchange ', 'Inventure Grow', 'Alankit', 'SHAH METACORP', 'ShreeGanesh Bio', 'Rhetan TMT', 'Reliance Comm', 'Sadhna Broadcas', 'Hind Motors', 'BSEL ALGO', 'Vikas Ecotech', 'Music Broadcast', 'ILandFS', 'Vishwaraj Sugar', 'Genus Paper', 'TGB Banquets', 'Teamo Productio', 'Kenvi Jewels', 'MEP Infra', 'Country Condos', 'Ansal Propertie', 'Healthy Life', 'Sadbhav Infra', 'HCL Info', 'Oriental Trimex', 'Kavveri Telecom', 'Ashapuri Gold', 'Ashapuri Gold', 'Sharika Enter', 'Mayukh Dealtrad', 'Pil Italica', 'MRC Agrotech', 'SEL', 'Leading Leasing', 'Leading Leasing', 'Gayatri Project', 'Gold Line', 'Cranes Software', 'Nagarjuna Fert', 'Indowind Energy', 'Veeram Sec', 'Dipna Pharma', 'Arshiya', 'Future Retail', 'Naturo Indiabul', 'SAL Steel', 'Ansal Housing', 'Future Consumer', 'Suvidhaa Info', 'GLCL', 'Madhucon Proj', 'Aksh Optifibre', 'A2Z Infra Eng', 'Zee Learn', 'Sarveshwar Food', 'Sarveshwar Food', 'Sharpline Broad', 'Siti Networks', 'HDIL', 'Cian Healthcare', 'Sun Retail ', 'Earum Pharmace', 'Gautam Gems', 'Nila Spaces', 'Ashima', 'VEL', 'Shree Secu', 'Shree Secu', 'Essar Shipping', 'Patel Integrate', 'Century Extr', 'PVP Ventures', 'Winsome Yarns', 'Tasty Dairy Spe', 'Transwarranty', 'Tarapur Trans', 'Energy Dev', 'BAG Films', 'Karnavati Fin', 'Karnavati Fin', 'GTL', 'RO Jewels', 'RO Jewels', 'Shree Rama News', 'Vinny Overseas', 'Vinny Overseas', 'JCL', 'Sanwaria Consum', 'S.M. Gold ', 'Visagar Polytex', 'Suumaya Corp.', 'Bhandari Hosier', 'Educomp Sol', 'Cerebra Int', 'KCD Industries', 'KCD Industries', 'Surana Telecom', 'Aanchal Ispat', 'Prajay Engineer', 'Mirc Electronic', 'ILandFS Trans', 'Burnpur Cement', 'Veerkrupa Jewel', 'SVS Ventures', 'Palm Jewels', 'Zenith SP&I', 'Sambhaav Media', 'E-Land Apparel', 'Jonjua Overseas', 'Goyal Aluminium', 'Goyal Aluminium', 'Heads UP Vent', 'Onelife Capital', 'Benara Bearings', 'SSIL', 'Vipul', 'G K P Printing', 'Compuage Info', 'Kanani Ind', 'Country Club', 'Jet Freight Log', 'Diligent Media ', 'Future Life', 'Sundaram Multi', 'SATCHMO HOLD', 'White Organic', 'AA Plus', 'Yaari Digital', 'California Soft', 'Omnipotent Ind', 'Lypsa Gems', 'Bartronics', 'Bartronics', 'Tijaria Polypip', 'Super Spinning', 'Rolta', 'Omkar Special', 'Mafia Trends', 'Visa Steel', 'Cinevista', 'Indiabulls Ent', 'Atal', 'Atal', 'Ganon Products ', 'Future Supply', 'Softrak Biotech', 'Shubham Polyspi', 'Excel Realty', 'Excel Realty', 'PBA Infra', 'Setco Auto', 'Patspin India', 'Kaushalya Infra', 'Amin Tannery', 'Adishakti Loha', 'Mohit Ind', 'Patron Exim', 'Premier']

# %%
# Funtion to count number of element in a list instead of len()-funtion

com_len=0
for i in com_name:
  com_len+=1
print(com_len)
# Out:
# 193

# %%
#cell to segregate row data from other

fulldata=s_table.findAll('tr')
fulldata=fulldata[1:]
# print(fulldata[0])
data=[]
for j in range(0,com_len*7,7):
  data.append(fulldata[j])

# print(data)

# %%
# Funtion to count number of element in a list instead of len()-funtion

data_len=0
for i in data:
  data_len+=1
print(data_len)
# Out:
# 193

# %%
# Extrating need data from <td> tag and elemenating unwanted html element

other_data=[]
for dat in data:
  row=dat.findAll('td')
  row=row[:7]
  row=[i.text for i in row]
  other_data.append(row)
  row[0]=red(row[0])
  l_df=len(sdf)
  # print(l_df)
  sdf.loc[l_df]=row
  # print(row)

# %%
sdf
# Out:
#        Company Name Group   High    Low Last Price  % Chg Value (Rs. cr.)
# 0          Yes Bank     A  19.65  19.20      19.31  -0.21           50.04
# 1     Vodafone Idea     A  13.55  13.20      13.27   1.61           41.36
# 2    Jaiprakash Pow     B  13.30  12.80      12.84  -1.91           15.74
# 3      Rattan Power     A   9.15   8.82       8.87  -0.78           10.85
# 4           Unitech     A   6.64   6.44       6.64   4.90            8.83
# ..              ...   ...    ...    ...        ...    ...             ...
# 188    Amin Tannery    B2   2.28   2.16       2.21   1.38            0.01
# 189  Adishakti Loha    B2  11.05  11.05      11.05   0.00            0.01
# 190       Mohit Ind     B  18.00  17.71      17.92   0.11            0.01
# 191     Patron Exim    B2   8.95   8.55       8.93   4.44            0.01
# 192         Premier     B   3.60   3.59       3.60   4.96            0.01
#
# [193 rows x 7 columns]

# %%
len(sdf)
# Out:
# 193

# %%
sdf.rename(columns={'% Chg':'Chg','Value (Rs. cr.)':'Value'},inplace=True)
sdf.to_csv('Loweststock.csv')

# %% [markdown]
# # Analyse the gathered table

# %%
# sdf.to_csv('loweststock.csv')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sdf=pd.read_csv('/content/drive/MyDrive/Mycolllections/loweststock.csv')
sdf.shape
# Out:
# (193, 7)

# %% [markdown]
# Removing Duplicates

# %%
sdf.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# Length: 193, dtype: bool

# %%
sdf=sdf.drop_duplicates()
sdf.shape
# Out:
# (175, 7)

# %%
temp1=sdf.duplicated()
temp1.describe()
# Out:
# count       175
# unique        1
# top       False
# freq        175
# dtype: object

# %%
#Checking for null value
sdf.isnull().sum()
# Out:
# Company Name    0
# Group           0
# High            0
# Low             0
# Last Price      0
# Chg             0
# Value           0
# dtype: int64

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  175 non-null    object
#  1   Group         175 non-null    object
#  2   High          175 non-null    object
#  3   Low           175 non-null    object
#  4   Last Price    175 non-null    object
#  5   Chg           175 non-null    object
#  6   Value         175 non-null    object
# dtypes: object(7)
# memory usage: 10.9+ KB

# %% [markdown]
# converting Object to float type

# %%
sdf[['High','Low','Last Price','Chg','Value']]=sdf[['High','Low','Last Price','Chg','Value']].astype(str).astype(float)
# Out:
# <ipython-input-165-c503f7333428>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sdf[['High','Low','Last Price','Chg','Value']]=sdf[['High','Low','Last Price','Chg','Value']].astype(str).astype(float)

# %%
sdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 175 entries, 0 to 192
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company Name  175 non-null    object
#  1   Group         175 non-null    object
#  2   High          175 non-null    float64
#  3   Low           175 non-null    float64
#  4   Last Price    175 non-null    float64
#  5   Chg           175 non-null    float64
#  6   Value         175 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 10.9+ KB

# %%
sdf.value_counts()
# Out:
# Company Name     Group  High   Low    Last Price  Chg    Value
# A2Z Infra Eng    B      10.49  10.49  10.49       -1.96  0.09     1
# SEACOAST SS      B2     2.77   2.64   2.76         4.55  4.67     1
# Rattan Power     A      9.15   8.82   8.87        -0.78  10.85    1
# Reliance Comm    A      1.80   1.76   1.79         1.70  0.36     1
# Reliance Home F  B2     2.34   2.23   2.34         4.93  0.72     1
#                                                                  ..
# Hathway Cable    A      20.44  19.65  19.74       -1.45  5.95     1
# Heads UP Vent    B      12.92  12.45  12.61       -1.64  0.03     1
# Healthy Life     B2     4.07   3.65   3.75        -7.41  0.18     1
# Hind Motors      B      17.83  17.06  17.31       -0.63  0.32     1
# Zenith SP&I      B      5.90   5.90   5.90        -1.99  0.04     1
# Length: 175, dtype: int64

# %%
sdf.describe()
# Out:
#              High         Low  Last Price         Chg       Value
# count  175.000000  175.000000  175.000000  175.000000  175.000000
# mean     9.826971    9.440000    9.616514    0.736457    1.198514
# std      5.805360    5.611017    5.690998    2.926045    5.203720
# min      0.380000    0.380000    0.380000   -7.410000    0.010000
# 25%      4.635000    4.435000    4.520000   -1.090000    0.030000
# 50%      9.000000    8.550000    8.800000    0.280000    0.080000
# 75%     14.520000   14.030000   14.440000    2.605000    0.235000
# max     20.440000   19.650000   19.870000   10.140000   50.040000

# %%
sdf.corr()
# Out:
# <ipython-input-169-a4f84409b963>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sdf.corr()
#                 High       Low  Last Price       Chg     Value
# High        1.000000  0.999008    0.999242 -0.061053  0.171405
# Low         0.999008  1.000000    0.999275 -0.059826  0.175353
# Last Price  0.999242  0.999275    1.000000 -0.040479  0.170593
# Chg        -0.061053 -0.059826   -0.040479  1.000000 -0.024541
# Value       0.171405  0.175353    0.170593 -0.024541  1.000000

# %%
sns.heatmap(sdf.corr(),annot=True)
# Out:
# <ipython-input-170-47bbb11615b1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(sdf.corr(),annot=True)
# <Axes: >

# %%
grp=sdf.groupby('Group')
grp.ngroups
# Out:
# 3

# %%
x=grp.size()
a=list(x.index)
b=list(x.values)

plt.figure(figsize=(5,5))
plt.bar(a,b,width=0.5)  #color='blue'
plt.xlabel('Group')
plt.ylabel('Number of stocks')
plt.title("Number of stock in each group")
# Out:
# Text(0.5, 1.0, 'Number of stock in each group')

# %%
sdf.groupby('Group')['Value'].agg(['mean']).plot(kind='bar')
# Out:
# <Axes: xlabel='Group'>

# %%
temp2=sdf.loc[sdf.Chg>=1]
temp2=temp2.reset_index()
temp2
# Out:
#     index     Company Name Group   High    Low  Last Price   Chg  Value
# 0       1    Vodafone Idea     A  13.55  13.20       13.27  1.61  41.36
# 1       4          Unitech     A   6.64   6.44        6.64  4.90   8.83
# 2      10      SEACOAST SS    B2   2.77   2.64        2.76  4.55   4.67
# 3      11        Zee Media     B  15.59  14.82       15.23  2.56   4.12
# 4      16        GTL Infra     B   1.09   1.05        1.08  1.89   2.87
# ..    ...              ...   ...    ...    ...         ...   ...    ...
# 69    185       Setco Auto     B   7.77   7.77        7.77  5.00   0.01
# 70    187  Kaushalya Infra     B   6.98   6.85        6.98  1.90   0.01
# 71    188     Amin Tannery    B2   2.28   2.16        2.21  1.38   0.01
# 72    191      Patron Exim    B2   8.95   8.55        8.93  4.44   0.01
# 73    192          Premier     B   3.60   3.59        3.60  4.96   0.01
#
# [74 rows x 8 columns]

# %%
plt.figure(figsize=(25,15))

sns.barplot(
    ci=False,
    data=temp2,
    y='Company Name',
    x='Chg'
)
# plt.xticks(rotation=45)
plt.title('plot to represent stock with there change in price percentage')
# Out:
# <ipython-input-175-010dd3e4ab91>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(
# Text(0.5, 1.0, 'plot to represent stock with there change in price percentage')

# %%
temp2=temp2.drop(['index'],axis=1)

# %%
sns.boxplot(temp2['Value'])
# Out:
# <Axes: >

# %%
temp2.groupby('Group').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Group'>

# %%
temp2.groupby('Group')['Value'].agg(['mean']).plot(kind='bar')
# Out:
# <Axes: xlabel='Group'>

# %%
plt.figure(figsize=(10,5))

sns.lineplot(
    ci=False,
    data=temp2,
    x='Last Price',                     #there is no reflextion from stock price to its value
    y='Value'
)

plt.title('Price of stock according to the value it posses')
# Out:
# <ipython-input-180-51fac5ef0f5a>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(
# Text(0.5, 1.0, 'Price of stock according to the value it posses')

# %%
temp3=temp2.loc[temp2.Group=='A']
temp3
# Out:
#        Company Name Group   High    Low  Last Price   Chg  Value
# 0     Vodafone Idea     A  13.55  13.20       13.27  1.61  41.36
# 1           Unitech     A   6.64   6.44        6.64  4.90   8.83
# 13    Reliance Comm     A   1.80   1.76        1.79  1.70   0.36
# 32  Future Consumer     A   0.84   0.81        0.84  2.44   0.10
# 36             HDIL     A   3.75   3.75        3.75  4.75   0.08

# %%
#Group A
plt.figure(figsize=(10,5))

sns.barplot(
    ci=False,
    data=temp3,
    x='Company Name',
    y='Last Price'
)
# plt.xticks(rotation=45)
plt.title('Stock belong to Group A with have increasing in recent days')
# Out:
# <ipython-input-182-934c0ea5514c>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(
# Text(0.5, 1.0, 'Stock belong to Group A with have increasing in recent days')

# %%
temp3=temp2.loc[temp2.Group=='B']
temp3.head()
# Out:
#      Company Name Group   High    Low  Last Price   Chg  Value
# 3       Zee Media     B  15.59  14.82       15.23  2.56   4.12
# 4       GTL Infra     B   1.09   1.05        1.08  1.89   2.87
# 10        Alankit     B  14.64  14.05       14.50  3.50   0.52
# 11  SHAH METACORP     B   3.45   3.27        3.36  2.44   0.47
# 14      BSEL ALGO     B  13.45  12.86       13.41  4.28   0.30

# %%
#Group B

plt.figure(figsize=(15,10))

sns.barplot(
    ci=False,
    data=temp3,
    y='Company Name',
    x='Last Price'
)
# plt.xticks(rotation=45)
plt.title('Stock belong to Group B with have increasing in recent days')
# Out:
# <ipython-input-184-3f6b12d93871>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(
# Text(0.5, 1.0, 'Stock belong to Group B with have increasing in recent days')

# %%
temp3=temp2.loc[temp2.Group=='B2']
temp3.head()
# Out:
#      Company Name Group  High   Low  Last Price   Chg  Value
# 2     SEACOAST SS    B2  2.77  2.64        2.76  4.55   4.67
# 5    Alstone Text    B2  0.61  0.59        0.61  3.39   1.54
# 6  Galactico Corp    B2  4.51  4.33        4.50  3.93   1.10
# 7  Akshar Spintex    B2  7.64  7.30        7.64  4.95   1.07
# 8      KBC Global    B2  2.10  2.02        2.10  3.96   0.76

# %%
#Group B2

plt.figure(figsize=(15,10))

sns.barplot(
    ci=False,
    data=temp3,
    y='Company Name',
    x='Last Price'
)
# plt.xticks(rotation=45)
plt.title('Stock belong to Group B2 with have increasing in recent days')
# Out:
# <ipython-input-186-9d88f74ae0ee>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(
# Text(0.5, 1.0, 'Stock belong to Group B2 with have increasing in recent days')
