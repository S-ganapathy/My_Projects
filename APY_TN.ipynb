# %% [markdown]
# # Tamil_Nadu_Crop_Production

# %%
# /content/drive/MyDrive/Mycolllections/Tamilnadu agriculture yield data.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cp=pd.read_csv('/content/drive/MyDrive/Mycolllections/Tamilnadu agriculture yield data.csv') #Importing dataset from drive

# %%
cp
# Out:
#        State_Name District_Name  Crop_Year      Season           Crop   Area  \
# 0      Tamil Nadu      ARIYALUR       2008      Kharif           Rice  24574
# 1      Tamil Nadu      ARIYALUR       2008  Whole Year      Arhar/Tur    209
# 2      Tamil Nadu      ARIYALUR       2008  Whole Year          Bajra    565
# 3      Tamil Nadu      ARIYALUR       2008  Whole Year         Banana    190
# 4      Tamil Nadu      ARIYALUR       2008  Whole Year      Cashewnut  31113
# ...           ...           ...        ...         ...            ...    ...
# 13542  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year  Small millets   1187
# 13543  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year      Sugarcane   2917
# 13544  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year   Sweet potato      4
# 13545  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year        Tapioca      4
# 13546  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year       Turmeric      4
#
#        Production
# 0             NaN
# ...

# %%
cp.dtypes
# Out:
# State_Name        object
# District_Name     object
# Crop_Year          int64
# Season            object
# Crop              object
# Area               int64
# Production       float64
# dtype: object

# %%
cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13547 entries, 0 to 13546
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     13547 non-null  object
#  1   District_Name  13547 non-null  object
#  2   Crop_Year      13547 non-null  int64
#  3   Season         13547 non-null  object
#  4   Crop           13547 non-null  object
#  5   Area           13547 non-null  int64
#  6   Production     13266 non-null  float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 741.0+ KB

# %%
cp.shape
# Out:
# (13547, 7)

# %%
cp.size
# Out:
# 94829

# %% [markdown]
# Finding any null values in the dataset

# %%
cp.isnull().sum()
# Out:
# State_Name         0
# District_Name      0
# Crop_Year          0
# Season             0
# Crop               0
# Area               0
# Production       281
# dtype: int64

# %%
cp=cp.dropna() #Droping the row with null values
cp.shape
# Out:
# (13266, 7)

# %% [markdown]
# Checking any duplicate row in  data

# %%
cp_temp=cp.duplicated()
cp_temp.describe()
# Out:
# count     13266
# unique        1
# top       False
# freq      13266
# dtype: object

# %%
cp
# Out:
#        State_Name District_Name  Crop_Year      Season           Crop   Area  \
# 22     Tamil Nadu      ARIYALUR       2009      Kharif           Rice  25978
# 23     Tamil Nadu      ARIYALUR       2009      Kharif  Small millets    404
# 24     Tamil Nadu      ARIYALUR       2009  Whole Year      Arhar/Tur    160
# 25     Tamil Nadu      ARIYALUR       2009  Whole Year          Bajra    644
# 26     Tamil Nadu      ARIYALUR       2009  Whole Year         Banana    134
# ...           ...           ...        ...         ...            ...    ...
# 13542  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year  Small millets   1187
# 13543  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year      Sugarcane   2917
# 13544  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year   Sweet potato      4
# 13545  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year        Tapioca      4
# 13546  Tamil Nadu  VIRUDHUNAGAR       2013  Whole Year       Turmeric      4
#
#        Production
# 22        80462.0
# ...

# %%
cp.value_counts()
# Out:
# State_Name  District_Name  Crop_Year  Season      Crop                Area   Production
# Tamil Nadu  ARIYALUR       2009       Kharif      Rice                25978  80462.0       1
#             THENI          2008       Whole Year  Arecanut            33     51.0          1
#                            2007       Whole Year  Ragi                34     73.0          1
#                                                   Sesamum             604    262.0         1
#                                                   Small millets       73     71.0          1
#                                                                                           ..
#             MADURAI        2003       Whole Year  Orange              3      6.0           1
#                                                   Other Citrus Fruit  37     0.0           1
#                                                   Other Fresh Fruits  208    0.0           1
# ...

# %%
print(cp.District_Name.unique())              #Number of district and count
print(len(cp.District_Name.unique()))
# Out:
# ['ARIYALUR' 'COIMBATORE' 'CUDDALORE' 'DHARMAPURI' 'DINDIGUL' 'ERODE'
#  'KANCHIPURAM' 'KANNIYAKUMARI' 'KARUR' 'KRISHNAGIRI' 'MADURAI'
#  'NAGAPATTINAM' 'NAMAKKAL' 'PERAMBALUR' 'PUDUKKOTTAI' 'RAMANATHAPURAM'
#  'SALEM' 'SIVAGANGA' 'THANJAVUR' 'THE NILGIRIS' 'THENI' 'THIRUVALLUR'
#  'THIRUVARUR' 'TIRUCHIRAPPALLI' 'TIRUNELVELI' 'TIRUPPUR' 'TIRUVANNAMALAI'
#  'TUTICORIN' 'VELLORE' 'VILLUPURAM' 'VIRUDHUNAGAR']
# 31

# %% [markdown]
# Observe by Districts

# %%
a=cp.groupby('District_Name')

# %%
type(a)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
a.ngroups
# Out:
# 31

# %%
a.size()
# Out:
# District_Name
# ARIYALUR           106
# COIMBATORE         533
# CUDDALORE          463
# DHARMAPURI         531
# DINDIGUL           595
# ERODE              551
# KANCHIPURAM        394
# KANNIYAKUMARI      251
# KARUR              457
# KRISHNAGIRI        328
# MADURAI            490
# NAGAPATTINAM       313
# NAMAKKAL           521
# PERAMBALUR         470
# PUDUKKOTTAI        423
# RAMANATHAPURAM     372
# SALEM              560
# SIVAGANGA          416
# THANJAVUR          409
# THE NILGIRIS       304
# THENI              517
# THIRUVALLUR        395
# THIRUVARUR         289
# TIRUCHIRAPPALLI    493
# TIRUNELVELI        527
# TIRUPPUR           114
# TIRUVANNAMALAI     489
# TUTICORIN          470
# VELLORE            504
# VILLUPURAM         490
# VIRUDHUNAGAR       491
# dtype: int64

# %%
a.get_group('THENI') #All the data belong to the a particular district
# Out:
#       State_Name District_Name  Crop_Year      Season           Crop  Area  \
# 8668  Tamil Nadu         THENI       1997      Kharif         Banana  1970
# 8669  Tamil Nadu         THENI       1997      Kharif     Horse-gram   592
# 8670  Tamil Nadu         THENI       1997      Kharif          Onion   882
# 8671  Tamil Nadu         THENI       1997      Kharif        Sesamum  1738
# 8672  Tamil Nadu         THENI       1997      Kharif  Small millets   716
# ...          ...           ...        ...         ...            ...   ...
# 9183  Tamil Nadu         THENI       2013  Whole Year  Small millets    36
# 9184  Tamil Nadu         THENI       2013  Whole Year      Sugarcane  6425
# 9185  Tamil Nadu         THENI       2013  Whole Year        Tapioca   899
# 9186  Tamil Nadu         THENI       2013  Whole Year        Tobacco     5
# 9187  Tamil Nadu         THENI       2013  Whole Year       Turmeric    18
#
#       Production
# 8668     34600.0
# 8669       300.0
# ...

# %%
#production from each district for all years

plt.figure(figsize=(20, 10))
sns.barplot(ci=False,
    data=cp,
    x='District_Name',
    y='Production'
)
plt.title("Total production for each district in TamilNadu")
plt.xticks(rotation=45);
# Out:
# <ipython-input-170-33d6a4ba94ae>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %%
#Area(Hectare) utilised by each district

plt.figure(figsize=(20, 10))
sns.barplot(ci=False,
    data=cp,
    x='District_Name',
    y='Area'
)
plt.title("Total Area used for each district in TamilNadu")
plt.xticks(rotation=45);
# Out:
# <ipython-input-171-63791080292c>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %%
a[('Area','Production')].agg(['max','min','count','mean'])
# Out:
# <ipython-input-172-c7556e1d6325>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   a[('Area','Production')].agg(['max','min','count','mean'])
#                    Area                            Production              \
#                     max min count          mean           max   min count
# District_Name
# ARIYALUR          31188   1   106   4114.226415  2.600000e+06   1.0   106
# COIMBATORE       167323   1   533   7214.954972  1.250800e+09   0.0   533
# CUDDALORE        205799   1   463  11244.799136  4.370000e+07   0.0   463
# DHARMAPURI       367554   1   531   9778.907721  1.241000e+08   0.0   531
# DINDIGUL         163104   1   595   5768.578151  5.749000e+08   0.0   595
# ERODE            137019   1   551   6789.784029  2.021000e+08   0.0   551
# KANCHIPURAM      230007   1   394   7940.878173  3.390000e+07   0.0   394
# ...

# %%
# temp=a.Crop_Year.unique()
# type(temp)
# temp.value_counts()

# %%
x=cp.groupby(['District_Name','Crop','Season'])['Crop']
y=x.size()
y.ARIYALUR #Type of crops yield for each season in ARIYALUR District
# Out:
# Crop               Season
# Arhar/Tur          Kharif        2
#                    Whole Year    3
# Bajra              Kharif        2
#                    Rabi          2
#                    Whole Year    1
# Banana             Whole Year    3
# Cashewnut          Whole Year    3
# Castor seed        Kharif        3
#                    Whole Year    2
# Coconut            Whole Year    3
# Coriander          Whole Year    3
# Cotton(lint)       Kharif        4
#                    Rabi          2
#                    Whole Year    1
# Dry chillies       Whole Year    3
# Groundnut          Kharif        4
#                    Rabi          2
#                    Whole Year    1
# Horse-gram         Rabi          1
# Jowar              Kharif        2
#                    Rabi          2
#                    Whole Year    1
# Maize              Kharif        4
#                    Rabi          2
#                    Whole Year    1
# Moong(Green Gram)  Kharif        3
# ...

# %%
#Production and Area District by season wise

z=cp.groupby(['District_Name','Season'])
z.describe()
# Out:
#                          Crop_Year                                          \
#                              count         mean       std     min      25%
# District_Name Season
# ARIYALUR      Kharif          41.0  2011.487805  1.286895  2009.0  2010.00
#               Rabi            16.0  2012.250000  1.000000  2011.0  2011.00
#               Whole Year      49.0  2010.510204  1.569533  2009.0  2009.00
# COIMBATORE    Kharif         181.0  2004.000000  4.892171  1997.0  2000.00
#               Rabi            32.0  2007.500000  5.951416  1998.0  2001.50
# ...                            ...          ...       ...     ...      ...
# VILLUPURAM    Rabi            30.0  2008.200000  5.579519  1998.0  2003.25
#               Whole Year     278.0  2004.812950  4.437400  1997.0  2002.00
# VIRUDHUNAGAR  Kharif         180.0  2004.027778  4.880048  1997.0  2000.00
#               Rabi            27.0  2008.925926  5.327187  1998.0  2004.50
# ...

# %%
#Name of the crops and count

print(cp.Crop.unique())
print(len(cp.Crop.unique()))
# Out:
# ['Rice' 'Small millets' 'Arhar/Tur' 'Bajra' 'Banana' 'Cashewnut'
#  'Castor seed' 'Coconut' 'Coriander' 'Cotton(lint)' 'Dry chillies'
#  'Groundnut' 'Jowar' 'Maize' 'Moong(Green Gram)' 'Onion' 'Ragi' 'Sesamum'
#  'Sugarcane' 'Sunflower' 'Sweet potato' 'Tapioca' 'Turmeric' 'Urad'
#  'Horse-gram' 'Tobacco' 'Black pepper' 'Cardamom' 'Gram' 'Pulses total'
#  'Total foodgrain' 'Wheat' 'Sannhamp' 'Korra' 'Samai' 'Guar seed'
#  'Other Cereals & Millets' 'Other Kharif pulses' 'Rapeseed &Mustard'
#  'Varagu' 'Ash Gourd' 'Beans & Mutter(Vegetable)' 'Beet Root' 'Bhindi'
#  'Bitter Gourd' 'Bottle Gourd' 'Brinjal' 'Cauliflower' 'Citrus Fruit'
#  'Cucumber' 'Drum Stick' 'Garlic' 'Grapes' 'Jack Fruit' 'Lab-Lab' 'Mango'
#  'Orange' 'Other Citrus Fruit' 'Other Fresh Fruits' 'Other Vegetables'
#  'Papaya' 'Pome Fruit' 'Pome Granet' 'Redish' 'Ribed Guard' 'Snak Guard'
#  'Tomato' 'Water Melon' 'Yam' 'Cabbage' 'Pump Kin' 'Dry ginger' 'Arecanut'
# ...

# %%
#Area utilised by each crop types

plt.figure(figsize=(20, 20))
sns.barplot(ci=False,
    data=cp,
    x='Area',
    y='Crop'
)
plt.title("Total Area used for crop production");
# Out:
# <ipython-input-177-05b6bf9e4cbb>:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %% [markdown]
# # Analysing for a particular Year-2003

# %%
print(cp.Crop_Year.unique())      #for how many year the data is available and count
print(len(cp.Crop_Year.unique()))
# Out:
# [2009 2010 2011 2012 2013 1997 1998 1999 2000 2001 2002 2003 2004 2005
#  2006 2007 2008]
# 17

# %%
cp_2003=cp.loc[cp.Crop_Year==2003]         #As all data is form tamilnadu so the state name column is not needed
cp_2003=cp_2003.drop(['State_Name'],axis=1)
cp_2003
# Out:
#       District_Name  Crop_Year      Season          Crop   Area  Production
# 322      COIMBATORE       2003      Kharif     Arhar/Tur    342       209.0
# 323      COIMBATORE       2003      Kharif         Bajra    500       575.0
# 324      COIMBATORE       2003      Kharif   Castor seed    205        76.0
# 325      COIMBATORE       2003      Kharif  Cotton(lint)   6881      8600.0
# 326      COIMBATORE       2003      Kharif     Groundnut  16629     14937.0
# ...             ...        ...         ...           ...    ...         ...
# 13275  VIRUDHUNAGAR       2003  Whole Year  Sweet potato     64       927.0
# 13276  VIRUDHUNAGAR       2003  Whole Year       Tapioca     30      1011.0
# 13277  VIRUDHUNAGAR       2003  Whole Year        Tomato    190      1928.0
# 13278  VIRUDHUNAGAR       2003  Whole Year   Water Melon      2         0.0
# 13279  VIRUDHUNAGAR       2003  Whole Year           Yam    165         0.0
#
# [1462 rows x 6 columns]

# %%
#production for each district in 2003

plt.figure(figsize=(20, 10))
sns.barplot(ci=False,
    data=cp_2003,
    x='District_Name',
    y='Production'
)
plt.title("Total production for each district in 2003")
plt.xticks(rotation=45);
# Out:
# <ipython-input-180-7be75c69226e>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %%
plt.figure(figsize=(20, 10))
sns.barplot(ci=False,
    data=cp_2003,
    x='District_Name',
    y='Area'
)
plt.title("Total production for each district in 2003")
plt.xticks(rotation=45);
# Out:
# <ipython-input-181-30b523b334e9>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %%
plt.figure(figsize=(20, 20))
sns.barplot(ci=False,
    data=cp_2003,
    x='Area',
    y='Crop'
)
plt.title("Total Area in hectare used in 2003 for production");
# Out:
# <ipython-input-182-7158d461a0d1>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %%
plt.figure(figsize=(20, 20))
sns.barplot(ci=False,
    data=cp_2003,
    x='Production',
    y='Crop'
)
plt.title("production of each crop in 2003");
# Out:
# <ipython-input-183-770ee9dc9405>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %%
#filtering for Kharif and Rabi season only

cp_03_sea=cp_2003.loc[cp_2003.Season!='Whole Year']
cp_03_sea
# Out:
#       District_Name  Crop_Year  Season           Crop   Area  Production
# 322      COIMBATORE       2003  Kharif      Arhar/Tur    342       209.0
# 323      COIMBATORE       2003  Kharif          Bajra    500       575.0
# 324      COIMBATORE       2003  Kharif    Castor seed    205        76.0
# 325      COIMBATORE       2003  Kharif   Cotton(lint)   6881      8600.0
# 326      COIMBATORE       2003  Kharif      Groundnut  16629     14937.0
# ...             ...        ...     ...            ...    ...         ...
# 13239  VIRUDHUNAGAR       2003  Kharif        Sesamum   3661       981.0
# 13240  VIRUDHUNAGAR       2003  Kharif  Small millets   1357       656.0
# 13241  VIRUDHUNAGAR       2003  Kharif      Sunflower    700       294.0
# 13242  VIRUDHUNAGAR       2003  Kharif           Urad   5426      2218.0
# 13243  VIRUDHUNAGAR       2003    Rabi           Gram    146        73.0
#
# [464 rows x 6 columns]

# %%
#comparing Kahrif and Rabi season production in 2003

plt.figure(figsize=(10, 5))
sns.lineplot(ci=False,
    data=cp_03_sea,
    x='Season',
    y='Production'
)
plt.title("Production for each season in 2003");
# Out:
# <ipython-input-185-e79ceccaae88>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.lineplot(ci=False,

# %%
#Area used for those two season

plt.figure(figsize=(10, 5))
sns.barplot(ci=False,
    data=cp_03_sea,
    x='Season',
    y='Area'
)
plt.title("Production for each season");
# Out:
# <ipython-input-186-945744b90383>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(ci=False,

# %% [markdown]
# # Gathering for each season

# %%
cp.Season.unique()
# Out:
# array(['Kharif', 'Whole Year', 'Rabi'], dtype=object)

# %%
b=cp.groupby('Season')
temp1=b.size()
temp1
# Out:
# Season
# Kharif        4668
# Rabi           660
# Whole Year    7938
# dtype: int64

# %%
b.Production.agg(['min','max','mean'])
# Out:
#             min           max          mean
# Season
# Kharif      0.0  8.314830e+05  2.802369e+04
# Rabi        0.0  1.640190e+05  5.972137e+03
# Whole Year  0.0  1.250800e+09  1.504370e+06

# %%
temp2=b.Crop.value_counts()
# type(temp2.Kharif.values)
d1=list(temp2.Kharif.index)
d1v=list(temp2.Kharif.values)

# %%
#To see which crop is cultivated in kharif season alone

plt.figure(figsize=(20, 20))
plt.pie(d1v,labels=d1)#autopct='%.0f%%'
plt.title('Prodution in preMonsoon (Kharif)')
plt.legend()

# %%
#whole year season production for all crop types


d2=list(temp2['Whole Year'].index)
d2v=list(temp2['Whole Year'].values)

plt.figure(figsize=(15,20))
plt.plot(d2v,d2)
plt.title('Whole Year production ')
plt.show()

# %% [markdown]
# # Study of rice prodution during 1997 to 2008

# %%
cp_rice=cp.loc[cp.Crop=='Rice']
cp_rice
# Out:
#        State_Name District_Name  Crop_Year  Season  Crop   Area  Production
# 22     Tamil Nadu      ARIYALUR       2009  Kharif  Rice  25978     80462.0
# 53     Tamil Nadu      ARIYALUR       2010  Kharif  Rice  25211     97869.0
# 63     Tamil Nadu      ARIYALUR       2011  Kharif  Rice  24097     97257.0
# 93     Tamil Nadu      ARIYALUR       2012  Kharif  Rice  17523     36392.0
# 107    Tamil Nadu      ARIYALUR       2013  Kharif  Rice  24437    131658.0
# ...           ...           ...        ...     ...   ...    ...         ...
# 13422  Tamil Nadu  VIRUDHUNAGAR       2009  Kharif  Rice  26617     64716.0
# 13458  Tamil Nadu  VIRUDHUNAGAR       2010  Kharif  Rice  30568     94515.0
# 13469  Tamil Nadu  VIRUDHUNAGAR       2011  Kharif  Rice  29658    118469.0
# 13504  Tamil Nadu  VIRUDHUNAGAR       2012  Kharif  Rice  22973     40467.0
# 13519  Tamil Nadu  VIRUDHUNAGAR       2013  Kharif  Rice  16470     68146.0
#
# [496 rows x 7 columns]

# %%
cp_rice['Season']=='Rabi' #no Rice production in winter season
# Out:
# 22       False
# 53       False
# 63       False
# 93       False
# 107      False
#          ...
# 13422    False
# 13458    False
# 13469    False
# 13504    False
# 13519    False
# Name: Season, Length: 496, dtype: bool

# %%
#Rice production in each season

plt.figure(figsize=(10, 10))
sns.histplot(
    data=cp_rice,
    x='Season',
    y='Production'
)
plt.title("Rice production in each season");

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(
    data=cp_rice,
    x='Crop_Year',
    y='Production'
)

plt.title("Rice production from 1998-2012 in Tamil nadu");

# %%
#District wise Rice prodution
plt.figure(figsize=(12, 15))
sns.barplot(
    data=cp_rice,
    y='District_Name',
    x='Production'
)
plt.title("Rice production in each district of Tamil nadu");

# %%
#Amount of area used and production yield
plt.figure(figsize=(20,10))
sns.lineplot(
    data=cp_rice,
    y='Area',
    x='Production'
)
plt.title("Area use in hectare to production");
